# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris_df = pd.read_csv("iris.csv")

# %%
iris_df.shape #shape of the data frame
# Out:
# (150, 5)

# %%
iris_df.columns #columns of the dataframe
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
iris_df.head() #first 5 rows of the dataset
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_df["variety"].value_counts() #no. of data points from each class
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# # Scatter Plot

# %%
iris_df.plot(kind="scatter", x="sepal.length",y="sepal.width")
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris_df,hue="variety",height=4) \
              .map(plt.scatter,"sepal.length","sepal.width") \
              .add_legend()
plt.show()

# %% [markdown]
# # Pair Plot

# %%
sns.set_style("whitegrid")
sns.pairplot(iris_df,hue="variety",height=4)
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris_df,hue="variety",height=4) \
              .map(sns.histplot,"petal.length") \
              .add_legend()
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris_df,hue="variety",height=4) \
              .map(sns.kdeplot,"petal.length") \
              .add_legend()
plt.show()

# %% [markdown]
# # Mean, Median, Standard Deviation, Variance

# %%
iris_setosa = iris_df.loc[iris_df.variety=="Setosa"]
iris_versicolor = iris_df.loc[iris_df.variety=="Versicolor"]
iris_virginica = iris_df.loc[iris_df.variety=="Virginica"]

# %%
print(np.mean(iris_setosa["petal.length"]))
print(np.mean(iris_versicolor["petal.length"]))
print(np.mean(iris_virginica["petal.length"]))
# Out:
# 1.4620000000000002
# 4.26
# 5.552

# %%
print(np.median(iris_setosa["petal.length"]))
print(np.median(iris_versicolor["petal.length"]))
print(np.median(iris_virginica["petal.length"]))
# Out:
# 1.5
# 4.35
# 5.55

# %%
print(np.std(iris_setosa["petal.length"]))
print(np.std(iris_versicolor["petal.length"]))
print(np.std(iris_virginica["petal.length"]))
# Out:
# 0.17191858538273286
# 0.4651881339845204
# 0.5463478745268441

# %%
print(np.var(iris_setosa["petal.length"]))
print(np.var(iris_versicolor["petal.length"]))
print(np.var(iris_virginica["petal.length"]))
# Out:
# 0.02955600000000001
# 0.21640000000000012
# 0.2984960000000002

# %% [markdown]
# # Quartiles, Prercentiles, IQR, MAD

# %%
#Quartiles
print(np.percentile(iris_setosa["petal.length"],np.arange(0,100,25)))
print(np.percentile(iris_versicolor["petal.length"],np.arange(0,100,25)))
print(np.percentile(iris_virginica["petal.length"],np.arange(0,100,25)))
# Out:
# [1.    1.4   1.5   1.575]
# [3.   4.   4.35 4.6 ]
# [4.5   5.1   5.55  5.875]

# %%
#90th percentile
print(np.percentile(iris_setosa["petal.length"],90))
print(np.percentile(iris_versicolor["petal.length"],90))
print(np.percentile(iris_virginica["petal.length"],90))
# Out:
# 1.7
# 4.8
# 6.31

# %%
from statsmodels import robust
print(robust.mad(iris_setosa["petal.length"]))
print(robust.mad(iris_versicolor["petal.length"]))
print(robust.mad(iris_virginica["petal.length"]))
# Out:
# 0.14826022185056031
# 0.5189107764769602
# 0.6671709983275211

# %% [markdown]
# # Box-Plots

# %%
sns.boxplot(y="petal.length",x="variety",data = iris_df)
plt.show()

# %% [markdown]
# # Violin-Plots

# %%
sns.violinplot(y="petal.length",x="variety",data = iris_df)
plt.show()
